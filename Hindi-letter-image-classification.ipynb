# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = image.load_img("training/hi/displayPanel_0_c11_67_flip_sharpen.jpg")

# %%
plt.imshow(img)

# %%
cv2.imread("training/hi/displayPanel_0_c11_67_flip_sharpen.jpg").shape
# Out:
# (64, 64, 3)

# %%
cv2.imread("training/hi/displayPanel_0_c11_67_flip_sharpen.jpg")
# Out:
# array([[[255, 254, 255],
#         [255, 254, 255],
#         [253, 251, 251],
#         ...,
#         [247, 250, 248],
#         [232, 235, 233],
#         [250, 253, 251]],
#
#        [[236, 231, 232],
#         [249, 244, 245],
#         [236, 234, 234],
#         ...,
#         [253, 255, 254],
#         [253, 255, 254],
#         [246, 249, 247]],
#
#        [[255, 254, 255],
#         [210, 205, 206],
#         [251, 249, 249],
#         ...,
#         [251, 252, 250],
#         [242, 243, 239],
#         [244, 245, 241]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
train = ImageDataGenerator(rescale= 1/255)
test = ImageDataGenerator(rescale= 1/255)

# %%
train_dataset = train.flow_from_directory('training/',
                                          target_size = (64,64),
                                         batch_size = 100,
                                         class_mode = 'binary')
# Out:
# Found 5875 images belonging to 2 classes.

# %%
train_dataset.class_indices
# Out:
# {'background': 0, 'hi': 1}

# %%
train_dataset.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
model = models.Sequential([
    layers.Conv2D(filters=8, kernel_size=(6, 6), activation='relu', input_shape=(64, 64, 3)),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu'),
    layers.AveragePooling2D((2, 2)),
    
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    layers.Flatten(),
    #layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    #layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(loss = 'binary_crossentropy',
             optimizer = tf. keras. optimizers. RMSprop(learning_rate=0.001),
             metrics = ['accuracy'])

# %%
model_fit = model.fit(train_dataset,
                     steps_per_epoch = 50,
                     epochs = 23)
# Out:
# Epoch 1/23
# 50/50 [==============================] - 7s 121ms/step - loss: 0.5112 - accuracy: 0.7554
# Epoch 2/23
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3987 - accuracy: 0.8259
# Epoch 3/23
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3272 - accuracy: 0.8702
# Epoch 4/23
# 50/50 [==============================] - 6s 123ms/step - loss: 0.2817 - accuracy: 0.8966
# Epoch 5/23
# 50/50 [==============================] - 6s 121ms/step - loss: 0.2606 - accuracy: 0.9062
# Epoch 6/23
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2384 - accuracy: 0.9138
# Epoch 7/23
# 50/50 [==============================] - 6s 121ms/step - loss: 0.2236 - accuracy: 0.9174
# Epoch 8/23
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2090 - accuracy: 0.9232
# Epoch 9/23
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1881 - accuracy: 0.9335
# Epoch 10/23
# ...

# %%
model.compile(loss = 'binary_crossentropy',
             optimizer = tf. keras. optimizers. RMSprop(learning_rate=0.0001),
             metrics = ['accuracy'])
model_fit = model.fit(train_dataset,
                     steps_per_epoch = 50,
                     epochs = 3)
# Out:
# Epoch 1/3
# 50/50 [==============================] - 7s 122ms/step - loss: 0.0641 - accuracy: 0.9797
# Epoch 2/3
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0543 - accuracy: 0.9815
# Epoch 3/3
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0518 - accuracy: 0.9847

# %%
model.compile(loss = 'binary_crossentropy',
             optimizer = tf. keras. optimizers. RMSprop(learning_rate=0.00001),
             metrics = ['accuracy'])
model_fit = model.fit(train_dataset,
                     steps_per_epoch = 50,
                     epochs = 3)
# Out:
# Epoch 1/3
# 50/50 [==============================] - 7s 121ms/step - loss: 0.0519 - accuracy: 0.9841
# Epoch 2/3
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0494 - accuracy: 0.9847
# Epoch 3/3
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0516 - accuracy: 0.9837

# %%
import os

# %%
for i in os.listdir('test'):
    img = image.load_img('test//'+i)
    print(i)
    
    X = image.img_to_array(img)
    X = np.expand_dims(X,axis =0)
    images = np.vstack([X])
    val = model.predict(images)
    if val == 0:
        print("background")
    else:
        print("hindi char")
    plt.imshow(img)
    plt.show()
# Out:
# 1.jpg
# hindi char
# 10.jpg
# background
# 11.jpg
# hindi char
# 12.jpg
# background
# 13.jpg
# hindi char
# 14.jpg
# background
# 15.jpg
# hindi char
# 16.jpg
# background
# 17.jpg
# background
# 18.jpg
# background
# 19.jpg
# hindi char
# 2.jpg
# background
# 20.jpg
# hindi char
# 21.jpg
# hindi char
# 22.jpg
# hindi char
# 23.jpg
# hindi char
# 24.jpg
# hindi char
# 25.jpg
# hindi char
# 26.jpg
# hindi char
# 27.jpg
# background
# 28.jpg
# hindi char
# 29.jpg
# hindi char
# 3.jpg
# hindi char
# 30.jpg
# hindi char
# 31.jpg
# background
# 32.jpg
# background
# 33.jpg
# background
# 34.jpg
# background
# 35.jpg
# background
# 36.jpg
# background
# 37.jpg
# background
# 38.jpg
# background
# 39.jpg
# background
# 4.jpg
# background
# 40.jpg
# background
# 41.jpg
# background
# 42.jpg
# hindi char
# 43.jpg
# background
# 44.jpg
# background
# 45.jpg
# background
# 46.jpg
# hindi char
# 47.jpg
# background
# 48.jpg
# hindi char
# 49.jpg
# background
# 5.jpg
# hindi char
# 50.jpg
# ...

# %%
import random
import json
# from utils.io import write_json

def write_json(filename, result):
    with open(filename, 'w') as outfile:
        json.dump(result, outfile)

def read_json(filename):
    with open(filename, 'r') as outfile:
        data =  json.load(outfile)
    return data

def generate_sample_file(filename):
    res = {}
    for  i in range(1,99):
        y = 1
        test_set = str(i) + '.jpg'
        img = image.load_img('test//'+test_set)
        X = image.img_to_array(img)
        X = np.expand_dims(X,axis =0)
        images = np.vstack([X])
        val = model.predict(images)
        if val == 0:
            res[test_set] = 0
        elif val == 1:
            res[test_set] = 1

    write_json(filename, res)

# %%
if __name__ == '__main__':
    generate_sample_file('./sample_result2.json')
